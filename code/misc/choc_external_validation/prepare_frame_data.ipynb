# %%
import json
import pandas as pd
import glob

# %%
data_dir = "/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images"
mapping_json = "patient_echoclip_mapping Feb 24 2022.json"

# %% [markdown]
# ## Clip-patient mapping

# %%
with open(f"{data_dir}/{mapping_json}", "r") as f:
    mapping = json.load(f)

df = pd.DataFrame({'patient_id': k, 'clip_id': v} for k,v in mapping.items()).explode('clip_id')
all_clips = set(df['clip_id'])

df
# Out:
#      patient_id      clip_id
# 0      PATIENT1    ECHOCLIP1
# 1      PATIENT2    ECHOCLIP2
# 1      PATIENT2  ECHOCLIP278
# 2      PATIENT3    ECHOCLIP3
# 2      PATIENT3  ECHOCLIP115
# ..          ...          ...
# 296  PATIENT297  ECHOCLIP451
# 297  PATIENT298  ECHOCLIP452
# 297  PATIENT298  ECHOCLIP453
# 298  PATIENT299  ECHOCLIP456
# 299  PATIENT300  ECHOCLIP461
#
# [461 rows x 2 columns]

# %%
mapping
# Out:
# {'PATIENT1': ['ECHOCLIP1'],
#  'PATIENT2': ['ECHOCLIP2', 'ECHOCLIP278'],
#  'PATIENT3': ['ECHOCLIP3', 'ECHOCLIP115'],
#  'PATIENT4': ['ECHOCLIP4', 'ECHOCLIP221'],
#  'PATIENT5': ['ECHOCLIP5'],
#  'PATIENT6': ['ECHOCLIP6', 'ECHOCLIP387'],
#  'PATIENT7': ['ECHOCLIP7', 'ECHOCLIP190', 'ECHOCLIP191', 'ECHOCLIP261'],
#  'PATIENT8': ['ECHOCLIP8', 'ECHOCLIP38', 'ECHOCLIP293', 'ECHOCLIP294'],
#  'PATIENT9': ['ECHOCLIP9', 'ECHOCLIP43'],
#  'PATIENT10': ['ECHOCLIP10'],
#  'PATIENT11': ['ECHOCLIP11'],
#  'PATIENT12': ['ECHOCLIP12'],
#  'PATIENT13': ['ECHOCLIP13'],
#  'PATIENT14': ['ECHOCLIP14'],
#  'PATIENT15': ['ECHOCLIP15', 'ECHOCLIP76', 'ECHOCLIP252'],
#  'PATIENT16': ['ECHOCLIP16'],
#  'PATIENT17': ['ECHOCLIP17'],
#  'PATIENT18': ['ECHOCLIP18'],
#  'PATIENT19': ['ECHOCLIP19'],
#  'PATIENT20': ['ECHOCLIP20', 'ECHOCLIP454', 'ECHOCLIP455'],
#  'PATIENT21': ['ECHOCLIP21'],
#  'PATIENT22': ['ECHOCLIP22', 'ECHOCLIP153', 'ECHOCLIP154'],
#  'PATIENT23': ['ECHOCLIP23'],
#  'PATIENT24': ['ECHOCLIP24', 'ECHOCLIP109', 'ECHOCLIP279', 'ECHOCLIP280'],
#  'PATIENT25': ['ECHOCLIP25', 'ECHOCLIP26', 'ECHOCLIP110', 'ECHOCLIP111'],
#  'PATIENT26': ['ECHOCLIP27'],
#  'PATIENT27': ['ECHOCLIP28',
#   'ECHOCLIP29',
#   'ECHOCLIP30',
#   'ECHOCLIP31',
#   'ECHOCLIP112',
#   'ECHOCLIP113'],
#  'PATIENT28': ['ECHOCLIP32', 'ECHOCLIP114', 'ECHOCLIP218'],
#  'PATIENT29': ['ECHOCLIP33'],
#  'PATIENT30': ['ECHOCLIP34', 'ECHOCLIP35'],
#  'PATIENT31': ['ECHOCLIP36',
#   'ECHOCLIP120',
#   'ECHOCLIP121',
#   'ECHOCLIP223',
#   'ECHOCLIP224'],
#  'PATIENT32': ['ECHOCLIP37'],
#  'PATIENT33': ['ECHOCLIP39'],
#  'PATIENT34': ['ECHOCLIP40', 'ECHOCLIP125'],
#  'PATIENT35': ['ECHOCLIP41'],
#  'PATIENT36': ['ECHOCLIP42', 'ECHOCLIP126'],
#  'PATIENT37': ['ECHOCLIP44', 'ECHOCLIP313'],
#  'PATIENT38': ['ECHOCLIP45'],
#  'PATIENT39': ['ECHOCLIP46', 'ECHOCLIP186', 'ECHOCLIP319'],
#  'PATIENT40': ['ECHOCLIP47', 'ECHOCLIP83', 'ECHOCLIP226', 'ECHOCLIP398'],
#  'PATIENT41': ['ECHOCLIP48'],
#  'PATIENT42': ['ECHOCLIP49',
#   'ECHOCLIP50',
#   'ECHOCLIP266',
#   'ECHOCLIP329',
#   'ECHOCLIP419'],
#  'PATIENT43': ['ECHOCLIP51'],
#  'PATIENT44': ['ECHOCLIP52', 'ECHOCLIP53'],
#  'PATIENT45': ['ECHOCLIP54'],
#  'PATIENT46': ['ECHOCLIP55'],
#  'PATIENT47': ['ECHOCLIP56'],
#  'PATIENT48': ['ECHOCLIP57'],
#  'PATIENT49': ['ECHOCLIP58',
#   'ECHOCLIP140',
#   'ECHOCLIP233',
#   'ECHOCLIP234',
#   'ECHOCLIP235',
#   'ECHOCLIP348'],
#  'PATIENT50': ['ECHOCLIP59', 'ECHOCLIP141'],
#  'PATIENT51': ['ECHOCLIP60'],
#  'PATIENT52': ['ECHOCLIP61'],
#  'PATIENT53': ['ECHOCLIP62',
#   'ECHOCLIP149',
#   'ECHOCLIP150',
#   'ECHOCLIP151',
#   'ECHOCLIP208',
#   'ECHOCLIP457'],
#  'PATIENT54': ['ECHOCLIP63', 'ECHOCLIP64', 'ECHOCLIP198'],
#  'PATIENT55': ['ECHOCLIP65'],
#  'PATIENT56': ['ECHOCLIP66'],
#  'PATIENT57': ['ECHOCLIP67'],
#  'PATIENT58': ['ECHOCLIP68', 'ECHOCLIP102', 'ECHOCLIP156'],
#  'PATIENT59': ['ECHOCLIP69'],
#  'PATIENT60': ['ECHOCLIP70'],
#  'PATIENT61': ['ECHOCLIP71', 'ECHOCLIP368'],
#  'PATIENT62': ['ECHOCLIP72', 'ECHOCLIP158'],
#  'PATIENT63': ['ECHOCLIP73', 'ECHOCLIP178'],
#  'PATIENT64': ['ECHOCLIP74'],
#  'PATIENT65': ['ECHOCLIP75'],
#  'PATIENT66': ['ECHOCLIP77', 'ECHOCLIP78', 'ECHOCLIP273'],
#  'PATIENT67': ['ECHOCLIP79', 'ECHOCLIP391'],
#  'PATIENT68': ['ECHOCLIP80'],
#  'PATIENT69': ['ECHOCLIP81'],
#  'PATIENT70': ['ECHOCLIP82', 'ECHOCLIP256'],
#  'PATIENT71': ['ECHOCLIP84'],
#  'PATIENT72': ['ECHOCLIP85'],
#  'PATIENT73': ['ECHOCLIP86'],
#  'PATIENT74': ['ECHOCLIP87'],
#  'PATIENT75': ['ECHOCLIP88'],
#  'PATIENT76': ['ECHOCLIP89'],
#  'PATIENT77': ['ECHOCLIP90'],
#  'PATIENT78': ['ECHOCLIP91'],
#  'PATIENT79': ['ECHOCLIP92'],
#  'PATIENT80': ['ECHOCLIP93', 'ECHOCLIP199', 'ECHOCLIP264'],
#  'PATIENT81': ['ECHOCLIP94'],
#  'PATIENT82': ['ECHOCLIP95'],
#  'PATIENT83': ['ECHOCLIP96'],
#  'PATIENT84': ['ECHOCLIP97', 'ECHOCLIP98', 'ECHOCLIP204', 'ECHOCLIP205'],
#  'PATIENT85': ['ECHOCLIP99'],
#  'PATIENT86': ['ECHOCLIP100', 'ECHOCLIP101', 'ECHOCLIP217'],
#  'PATIENT87': ['ECHOCLIP103', 'ECHOCLIP152'],
#  'PATIENT88': ['ECHOCLIP104'],
#  'PATIENT89': ['ECHOCLIP105', 'ECHOCLIP277'],
#  'PATIENT90': ['ECHOCLIP106', 'ECHOCLIP107'],
#  'PATIENT91': ['ECHOCLIP108'],
#  'PATIENT92': ['ECHOCLIP116'],
#  'PATIENT93': ['ECHOCLIP117'],
#  'PATIENT94': ['ECHOCLIP118'],
#  'PATIENT95': ['ECHOCLIP119'],
#  'PATIENT96': ['ECHOCLIP122'],
#  'PATIENT97': ['ECHOCLIP123'],
#  'PATIENT98': ['ECHOCLIP124'],
#  'PATIENT99': ['ECHOCLIP127'],
#  'PATIENT100': ['ECHOCLIP128'],
#  'PATIENT101': ['ECHOCLIP129'],
#  'PATIENT102': ['ECHOCLIP130', 'ECHOCLIP330'],
#  'PATIENT103': ['ECHOCLIP131'],
#  'PATIENT104': ['ECHOCLIP132', 'ECHOCLIP335'],
#  'PATIENT105': ['ECHOCLIP133', 'ECHOCLIP134', 'ECHOCLIP337'],
#  'PATIENT106': ['ECHOCLIP135', 'ECHOCLIP230'],
#  'PATIENT107': ['ECHOCLIP136'],
#  'PATIENT108': ['ECHOCLIP137'],
#  'PATIENT109': ['ECHOCLIP138'],
#  'PATIENT110': ['ECHOCLIP139'],
#  'PATIENT111': ['ECHOCLIP142',
#   'ECHOCLIP236',
#   'ECHOCLIP237',
#   'ECHOCLIP352',
#   'ECHOCLIP353'],
#  'PATIENT112': ['ECHOCLIP143', 'ECHOCLIP144', 'ECHOCLIP145'],
#  'PATIENT113': ['ECHOCLIP146'],
#  'PATIENT114': ['ECHOCLIP147'],
#  'PATIENT115': ['ECHOCLIP148'],
#  'PATIENT116': ['ECHOCLIP155'],
#  'PATIENT117': ['ECHOCLIP157'],
#  'PATIENT118': ['ECHOCLIP159'],
#  'PATIENT119': ['ECHOCLIP160', 'ECHOCLIP161'],
#  'PATIENT120': ['ECHOCLIP162', 'ECHOCLIP243'],
#  'PATIENT121': ['ECHOCLIP163'],
#  'PATIENT122': ['ECHOCLIP164', 'ECHOCLIP372'],
#  'PATIENT123': ['ECHOCLIP165'],
#  'PATIENT124': ['ECHOCLIP166', 'ECHOCLIP167', 'ECHOCLIP245', 'ECHOCLIP246'],
#  'PATIENT125': ['ECHOCLIP168', 'ECHOCLIP283'],
#  'PATIENT126': ['ECHOCLIP169', 'ECHOCLIP170'],
#  'PATIENT127': ['ECHOCLIP171'],
#  'PATIENT128': ['ECHOCLIP172', 'ECHOCLIP173', 'ECHOCLIP174', 'ECHOCLIP376'],
#  'PATIENT129': ['ECHOCLIP175'],
#  'PATIENT130': ['ECHOCLIP176', 'ECHOCLIP445'],
#  'PATIENT131': ['ECHOCLIP177'],
#  'PATIENT132': ['ECHOCLIP179', 'ECHOCLIP305'],
#  'PATIENT133': ['ECHOCLIP180', 'ECHOCLIP312'],
#  'PATIENT134': ['ECHOCLIP181',
#   'ECHOCLIP248',
#   'ECHOCLIP249',
#   'ECHOCLIP250',
#   'ECHOCLIP251',
#   'ECHOCLIP269'],
#  'PATIENT135': ['ECHOCLIP182'],
#  'PATIENT136': ['ECHOCLIP183'],
#  'PATIENT137': ['ECHOCLIP184'],
#  'PATIENT138': ['ECHOCLIP185'],
#  'PATIENT139': ['ECHOCLIP187'],
#  'PATIENT140': ['ECHOCLIP188', 'ECHOCLIP403'],
#  'PATIENT141': ['ECHOCLIP189', 'ECHOCLIP259', 'ECHOCLIP260'],
#  'PATIENT142': ['ECHOCLIP192', 'ECHOCLIP262', 'ECHOCLIP328'],
#  'PATIENT143': ['ECHOCLIP193'],
#  'PATIENT144': ['ECHOCLIP194', 'ECHOCLIP424'],
#  'PATIENT145': ['ECHOCLIP195'],
#  'PATIENT146': ['ECHOCLIP196', 'ECHOCLIP435'],
#  'PATIENT147': ['ECHOCLIP197'],
#  'PATIENT148': ['ECHOCLIP200', 'ECHOCLIP201'],
#  'PATIENT149': ['ECHOCLIP202'],
#  'PATIENT150': ['ECHOCLIP203'],
#  'PATIENT151': ['ECHOCLIP206', 'ECHOCLIP207'],
#  'PATIENT152': ['ECHOCLIP209', 'ECHOCLIP458', 'ECHOCLIP459', 'ECHOCLIP460'],
#  'PATIENT153': ['ECHOCLIP210'],
#  'PATIENT154': ['ECHOCLIP211',
#   'ECHOCLIP212',
#   'ECHOCLIP213',
#   'ECHOCLIP214',
#   'ECHOCLIP215'],
#  'PATIENT155': ['ECHOCLIP216'],
#  'PATIENT156': ['ECHOCLIP219'],
#  'PATIENT157': ['ECHOCLIP220'],
#  'PATIENT158': ['ECHOCLIP222'],
#  'PATIENT159': ['ECHOCLIP225', 'ECHOCLIP311'],
#  'PATIENT160': ['ECHOCLIP227', 'ECHOCLIP325'],
#  'PATIENT161': ['ECHOCLIP228', 'ECHOCLIP229'],
#  'PATIENT162': ['ECHOCLIP231', 'ECHOCLIP342'],
#  'PATIENT163': ['ECHOCLIP232', 'ECHOCLIP344'],
#  'PATIENT164': ['ECHOCLIP238', 'ECHOCLIP268'],
#  'PATIENT165': ['ECHOCLIP239', 'ECHOCLIP360'],
#  'PATIENT166': ['ECHOCLIP240', 'ECHOCLIP362'],
#  'PATIENT167': ['ECHOCLIP241'],
#  'PATIENT168': ['ECHOCLIP242', 'ECHOCLIP367'],
#  'PATIENT169': ['ECHOCLIP244'],
#  'PATIENT170': ['ECHOCLIP247'],
#  'PATIENT171': ['ECHOCLIP253'],
#  'PATIENT172': ['ECHOCLIP254', 'ECHOCLIP388'],
#  'PATIENT173': ['ECHOCLIP255'],
#  'PATIENT174': ['ECHOCLIP257'],
#  'PATIENT175': ['ECHOCLIP258', 'ECHOCLIP406'],
#  'PATIENT176': ['ECHOCLIP263'],
#  'PATIENT177': ['ECHOCLIP265', 'ECHOCLIP417', 'ECHOCLIP434'],
#  'PATIENT178': ['ECHOCLIP267'],
#  'PATIENT179': ['ECHOCLIP270'],
#  'PATIENT180': ['ECHOCLIP271'],
#  'PATIENT181': ['ECHOCLIP272'],
#  'PATIENT182': ['ECHOCLIP274'],
#  'PATIENT183': ['ECHOCLIP275'],
#  'PATIENT184': ['ECHOCLIP276'],
#  'PATIENT185': ['ECHOCLIP281', 'ECHOCLIP282'],
#  'PATIENT186': ['ECHOCLIP284'],
#  'PATIENT187': ['ECHOCLIP285'],
#  'PATIENT188': ['ECHOCLIP286'],
#  'PATIENT189': ['ECHOCLIP287'],
#  'PATIENT190': ['ECHOCLIP288'],
#  'PATIENT191': ['ECHOCLIP289', 'ECHOCLIP290'],
#  'PATIENT192': ['ECHOCLIP291'],
#  'PATIENT193': ['ECHOCLIP292'],
#  'PATIENT194': ['ECHOCLIP295'],
#  'PATIENT195': ['ECHOCLIP296'],
#  'PATIENT196': ['ECHOCLIP297'],
#  'PATIENT197': ['ECHOCLIP298', 'ECHOCLIP299'],
#  'PATIENT198': ['ECHOCLIP300'],
#  'PATIENT199': ['ECHOCLIP301'],
#  'PATIENT200': ['ECHOCLIP302'],
#  'PATIENT201': ['ECHOCLIP303'],
#  'PATIENT202': ['ECHOCLIP304'],
#  'PATIENT203': ['ECHOCLIP306', 'ECHOCLIP307'],
#  'PATIENT204': ['ECHOCLIP308', 'ECHOCLIP309', 'ECHOCLIP310'],
#  'PATIENT205': ['ECHOCLIP314'],
#  'PATIENT206': ['ECHOCLIP315'],
#  'PATIENT207': ['ECHOCLIP316'],
#  'PATIENT208': ['ECHOCLIP317'],
#  'PATIENT209': ['ECHOCLIP318'],
#  'PATIENT210': ['ECHOCLIP320', 'ECHOCLIP321'],
#  'PATIENT211': ['ECHOCLIP322'],
#  'PATIENT212': ['ECHOCLIP323', 'ECHOCLIP324'],
#  'PATIENT213': ['ECHOCLIP326'],
#  'PATIENT214': ['ECHOCLIP327'],
#  'PATIENT215': ['ECHOCLIP331'],
#  'PATIENT216': ['ECHOCLIP332'],
#  'PATIENT217': ['ECHOCLIP333'],
#  'PATIENT218': ['ECHOCLIP334'],
#  'PATIENT219': ['ECHOCLIP336'],
#  'PATIENT220': ['ECHOCLIP338'],
#  'PATIENT221': ['ECHOCLIP339', 'ECHOCLIP340'],
#  'PATIENT222': ['ECHOCLIP341'],
#  'PATIENT223': ['ECHOCLIP343'],
#  'PATIENT224': ['ECHOCLIP345'],
#  'PATIENT225': ['ECHOCLIP346', 'ECHOCLIP347'],
#  'PATIENT226': ['ECHOCLIP349'],
#  'PATIENT227': ['ECHOCLIP350'],
#  'PATIENT228': ['ECHOCLIP351'],
#  'PATIENT229': ['ECHOCLIP354'],
#  'PATIENT230': ['ECHOCLIP355', 'ECHOCLIP436'],
#  'PATIENT231': ['ECHOCLIP356'],
#  'PATIENT232': ['ECHOCLIP357', 'ECHOCLIP358'],
#  'PATIENT233': ['ECHOCLIP359'],
#  'PATIENT234': ['ECHOCLIP361'],
#  'PATIENT235': ['ECHOCLIP363', 'ECHOCLIP364'],
#  'PATIENT236': ['ECHOCLIP365'],
#  'PATIENT237': ['ECHOCLIP366'],
#  'PATIENT238': ['ECHOCLIP369'],
#  'PATIENT239': ['ECHOCLIP370'],
#  'PATIENT240': ['ECHOCLIP371'],
#  'PATIENT241': ['ECHOCLIP373'],
#  'PATIENT242': ['ECHOCLIP374'],
#  'PATIENT243': ['ECHOCLIP375'],
#  'PATIENT244': ['ECHOCLIP377'],
#  'PATIENT245': ['ECHOCLIP378'],
#  'PATIENT246': ['ECHOCLIP379'],
#  'PATIENT247': ['ECHOCLIP380'],
#  'PATIENT248': ['ECHOCLIP381'],
#  'PATIENT249': ['ECHOCLIP382'],
#  'PATIENT250': ['ECHOCLIP383'],
#  'PATIENT251': ['ECHOCLIP384', 'ECHOCLIP437'],
#  'PATIENT252': ['ECHOCLIP385', 'ECHOCLIP386'],
#  'PATIENT253': ['ECHOCLIP389'],
#  'PATIENT254': ['ECHOCLIP390'],
#  'PATIENT255': ['ECHOCLIP392'],
#  'PATIENT256': ['ECHOCLIP393'],
#  'PATIENT257': ['ECHOCLIP394'],
#  'PATIENT258': ['ECHOCLIP395'],
#  'PATIENT259': ['ECHOCLIP396'],
#  'PATIENT260': ['ECHOCLIP397'],
#  'PATIENT261': ['ECHOCLIP399'],
#  'PATIENT262': ['ECHOCLIP400'],
#  'PATIENT263': ['ECHOCLIP401'],
#  'PATIENT264': ['ECHOCLIP402'],
#  'PATIENT265': ['ECHOCLIP404'],
#  'PATIENT266': ['ECHOCLIP405'],
#  'PATIENT267': ['ECHOCLIP407'],
#  'PATIENT268': ['ECHOCLIP408'],
#  'PATIENT269': ['ECHOCLIP409', 'ECHOCLIP410'],
#  'PATIENT270': ['ECHOCLIP411'],
#  'PATIENT271': ['ECHOCLIP412'],
#  'PATIENT272': ['ECHOCLIP413'],
#  'PATIENT273': ['ECHOCLIP414'],
#  'PATIENT274': ['ECHOCLIP415'],
#  'PATIENT275': ['ECHOCLIP416'],
#  'PATIENT276': ['ECHOCLIP418'],
#  'PATIENT277': ['ECHOCLIP420', 'ECHOCLIP421'],
#  'PATIENT278': ['ECHOCLIP422'],
#  'PATIENT279': ['ECHOCLIP423'],
#  'PATIENT280': ['ECHOCLIP425'],
#  'PATIENT281': ['ECHOCLIP426'],
#  'PATIENT282': ['ECHOCLIP427'],
#  'PATIENT283': ['ECHOCLIP428', 'ECHOCLIP429'],
#  'PATIENT284': ['ECHOCLIP430'],
#  'PATIENT285': ['ECHOCLIP431'],
#  'PATIENT286': ['ECHOCLIP432'],
#  'PATIENT287': ['ECHOCLIP433'],
#  'PATIENT288': ['ECHOCLIP438'],
#  'PATIENT289': ['ECHOCLIP439', 'ECHOCLIP440', 'ECHOCLIP441', 'ECHOCLIP442'],
#  'PATIENT290': ['ECHOCLIP443'],
#  'PATIENT291': ['ECHOCLIP444'],
#  'PATIENT292': ['ECHOCLIP446'],
#  'PATIENT293': ['ECHOCLIP447'],
#  'PATIENT294': ['ECHOCLIP448'],
#  'PATIENT295': ['ECHOCLIP449'],
#  'PATIENT296': ['ECHOCLIP450'],
#  'PATIENT297': ['ECHOCLIP451'],
#  'PATIENT298': ['ECHOCLIP452', 'ECHOCLIP453'],
#  'PATIENT299': ['ECHOCLIP456'],
#  'PATIENT300': ['ECHOCLIP461']}

# %% [markdown]
# ## Create frame csv used in pipeline

# %%
# use glob to get all jpg files in the data directory
jpg_files = glob.glob(f"{data_dir}/**/*.jpg", recursive=True)

# remove those with Train_PDAfiltered in the path
# jpg_files = [f for f in jpg_files if "Train_PDAfiltered" not in f]

jpg_files
# Out:
# ['/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_027.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_028.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_029.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_030.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_031.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_032.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_033.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_034.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_035.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_036.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_037.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_038.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_039.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_040.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_041.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_042.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_043.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_044.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_045.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_046.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_047.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_048.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_049.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_050.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_051.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_052.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_053.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_054.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_055.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_056.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_057.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_058.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_059.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_060.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_061.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_062.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_063.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_064.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP274/NEG_ECHOCLIP274_065.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_027.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_028.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_029.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_030.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_031.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_032.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_033.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_034.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_035.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_036.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_037.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_038.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_039.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_040.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_041.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP279/NEG_ECHOCLIP279_042.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP280/NEG_ECHOCLIP280_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_027.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_028.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_029.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_030.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP284/NEG_ECHOCLIP284_031.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_027.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_028.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_029.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_030.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_031.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_032.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP285/NEG_ECHOCLIP285_033.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_027.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_028.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_029.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_030.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_031.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_032.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_033.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_034.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_035.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_036.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_037.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_038.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_039.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_040.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_041.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_042.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_043.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_044.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_045.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_046.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_047.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_048.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_049.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_050.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_051.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_052.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_053.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_054.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_055.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_056.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_057.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_058.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_059.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_060.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_061.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_062.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_063.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_064.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_065.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_066.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_067.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_068.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_069.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_070.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_071.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP286/NEG_ECHOCLIP286_072.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP300/NEG_ECHOCLIP300_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_027.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_028.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_029.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_030.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_031.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_032.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_033.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_034.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_035.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_036.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_037.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_038.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_039.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_040.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_041.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_042.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_043.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_044.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_045.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP304/NEG_ECHOCLIP304_046.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP318/NEG_ECHOCLIP318_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_027.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_028.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_029.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_030.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_031.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_032.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_033.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_034.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_035.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_036.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_037.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_038.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_039.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_040.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_041.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_042.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_043.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_044.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP322/NEG_ECHOCLIP322_045.jpg',
# ...
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_193.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_194.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_195.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_196.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_197.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_198.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_199.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_200.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_201.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_202.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_203.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_204.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_205.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_206.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_207.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_208.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_209.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_210.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_211.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_212.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_213.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_214.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_215.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_216.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_217.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_218.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_219.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_220.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_221.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_222.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_223.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_224.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_225.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_226.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_227.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP413/NEG_ECHOCLIP413_228.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_019.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_020.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_021.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_022.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_023.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_024.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_025.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_026.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_027.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_028.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_029.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_030.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_031.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_032.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_033.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_034.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_035.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_036.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_037.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_038.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_039.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_040.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_041.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_042.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_043.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_044.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_045.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_046.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_047.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_048.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_049.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_050.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_051.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_052.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_053.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_054.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_055.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_056.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_057.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_058.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_059.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_060.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_061.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_062.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_063.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_064.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_065.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_066.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_067.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_068.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_069.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_070.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_071.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_072.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_073.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_074.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_075.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_076.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_077.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_078.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_079.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_080.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP414/NEG_ECHOCLIP414_081.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_001.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_002.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_003.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_004.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_005.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_006.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_007.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_008.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_009.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_010.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_011.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_012.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_013.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_014.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_015.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_016.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_017.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_018.jpg',
#  '/project/dane2/wficai/pda/external_validation/CHOC/CHOC_echo_images/Test/NEG/ECHOCLIP415/NEG_ECHOCLIP415_019.jpg',
#  ...]

# %%
# build the dataframe from the file paths
def extract_record(file_path):
    split = file_path.split("/")
    condition_dict = dict(
        POS = "pda",
        NEG = "nopda"
    )
    split_dict = dict(
        Train = "TRAIN",
        Train_pdaFiltered = "TRAIN_PDAFILTERED",
        Test = "TEST",
        Val = "VAL"
    )

    record = dict(
        clip_id = split[-2],
        patient_type = condition_dict[split[-3]],
        Split = split_dict[split[-4]],
        png_path = file_path
    )

    return record

df_frames = pd.DataFrame([extract_record(f) for f in jpg_files])
df_frames
# Out:
#            clip_id patient_type Split  \
# 0      ECHOCLIP274        nopda  TEST
# 1      ECHOCLIP274        nopda  TEST
# 2      ECHOCLIP274        nopda  TEST
# 3      ECHOCLIP274        nopda  TEST
# 4      ECHOCLIP274        nopda  TEST
# ...            ...          ...   ...
# 30604   ECHOCLIP94          pda   VAL
# 30605   ECHOCLIP94          pda   VAL
# 30606   ECHOCLIP94          pda   VAL
# 30607   ECHOCLIP94          pda   VAL
# 30608   ECHOCLIP94          pda   VAL
#
#                                                 png_path
# 0      /project/dane2/wficai/pda/external_validation/...
# 1      /project/dane2/wficai/pda/external_validation/...
# 2      /project/dane2/wficai/pda/external_validation/...
# 3      /project/dane2/wficai/pda/external_validation/...
# 4      /project/dane2/wficai/pda/external_validation/...
# ...                                                  ...
# 30604  /project/dane2/wficai/pda/external_validation/...
# 30605  /project/dane2/wficai/pda/external_validation/...
# 30606  /project/dane2/wficai/pda/external_validation/...
# 30607  /project/dane2/wficai/pda/external_validation/...
# 30608  /project/dane2/wficai/pda/external_validation/...
#
# [30609 rows x 4 columns]

# %%
# merge the frame and patient data
df_merged = df.merge(df_frames)

df_merged
# Out:
#        patient_id      clip_id patient_type              Split  \
# 0        PATIENT1    ECHOCLIP1          pda                VAL
# 1        PATIENT1    ECHOCLIP1          pda                VAL
# 2        PATIENT1    ECHOCLIP1          pda                VAL
# 3        PATIENT1    ECHOCLIP1          pda                VAL
# 4        PATIENT1    ECHOCLIP1          pda                VAL
# ...           ...          ...          ...                ...
# 30604  PATIENT300  ECHOCLIP461        nopda  TRAIN_PDAFILTERED
# 30605  PATIENT300  ECHOCLIP461        nopda  TRAIN_PDAFILTERED
# 30606  PATIENT300  ECHOCLIP461        nopda  TRAIN_PDAFILTERED
# 30607  PATIENT300  ECHOCLIP461        nopda  TRAIN_PDAFILTERED
# 30608  PATIENT300  ECHOCLIP461        nopda  TRAIN_PDAFILTERED
#
#                                                 png_path
# 0      /project/dane2/wficai/pda/external_validation/...
# 1      /project/dane2/wficai/pda/external_validation/...
# 2      /project/dane2/wficai/pda/external_validation/...
# 3      /project/dane2/wficai/pda/external_validation/...
# 4      /project/dane2/wficai/pda/external_validation/...
# ...                                                  ...
# 30604  /project/dane2/wficai/pda/external_validation/...
# 30605  /project/dane2/wficai/pda/external_validation/...
# 30606  /project/dane2/wficai/pda/external_validation/...
# 30607  /project/dane2/wficai/pda/external_validation/...
# 30608  /project/dane2/wficai/pda/external_validation/...
#
# [30609 rows x 5 columns]

# %%
# number of frames
df_merged.groupby(['Split', 'patient_type'], as_index=False)["png_path"].count()
# Out:
#                Split patient_type  png_path
# 0               TEST        nopda      3072
# 1               TEST          pda      2568
# 2              TRAIN        nopda      9147
# 3              TRAIN          pda       852
# 4  TRAIN_PDAFILTERED        nopda      9149
# 5  TRAIN_PDAFILTERED          pda       852
# 6                VAL        nopda      2301
# 7                VAL          pda      2668

# %%
# numbver of clips
df_merged.groupby(['Split'], as_index=False)["clip_id"].nunique()
# Out:
#                Split  clip_id
# 0               TEST       72
# 1              TRAIN      129
# 2  TRAIN_PDAFILTERED      153
# 3                VAL       74

# %%
df_merged.groupby(['Split', 'patient_type']).clip_id.nunique()
# Out:
# Split              patient_type
# TEST               nopda            38
#                    pda              34
# TRAIN              nopda           116
#                    pda              13
# TRAIN_PDAFILTERED  nopda           116
#                    pda              37
# VAL                nopda            36
#                    pda              38
# Name: clip_id, dtype: int64

# %%
df_merged.groupby(['Split', 'patient_type']).patient_id.nunique()
# Out:
# Split              patient_type
# TEST               nopda           31
#                    pda             25
# TRAIN              nopda           99
#                    pda             10
# TRAIN_PDAFILTERED  nopda           99
#                    pda             32
# VAL                nopda           30
#                    pda             27
# Name: patient_id, dtype: int64

# %%
# save the file
df_merged.to_csv(f"{data_dir}/pda_train_val_test.csv", index=False)
