# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
##
## Config

k_fold_splits = 6
rng_seed = 42

# data paths
frame = '/zfs/wficai/pda/model_data/20221028_frame.csv'
video = '/zfs/wficai/pda/model_data/20221028_video.csv'
study = '/zfs/wficai/pda/model_data/20221028_study.csv'
patient_study = '/zfs/wficai/pda/model_data/20221028_patient_study.csv'
patient = '/zfs/wficai/pda/model_data/20221028_patient.csv'

# output frames file
output_csv = '/zfs/wficai/pda/model_data/pda_train_val_test.csv'

# load data
df_frame = pd.read_csv(frame)
df_video = pd.read_csv(video)
df_study = pd.read_csv(study)
df_patient_study = pd.read_csv(patient_study)
df_patient = pd.read_csv(patient)

# %%
# split data
df_patient['cv_split'] = None
cv = StratifiedKFold(n_splits=k_fold_splits, shuffle=True, random_state=rng_seed)
for ix, (train_ix, test_ix) in enumerate(cv.split(X = df_patient, y = df_patient.patient_type)):
    df_patient.iloc[test_ix, -1] = ix

# %%
split_map = {i: 'TRAIN' for i in range(k_fold_splits)}
split_map[k_fold_splits-1] = 'TEST'
split_map[k_fold_splits-2] = 'VAL'
df_patient['Split'] = df_patient.cv_split.map(split_map)

# %%
df_patient.cv_split.value_counts()
# Out:
# 2    11
# 4    11
# 0    11
# 3    11
# 5    11
# 1    11
# Name: cv_split, dtype: int64

# %%
df_patient.Split.value_counts()
# Out:
# TRAIN    44
# VAL      11
# TEST     11
# Name: Split, dtype: int64

# %% [markdown]
# ### Design subsamples for testing sample efficiency

# %%
# use logarithmically spaced subsample fractions
start = 5
stop = 44
num_steps = 6
subset_nums = np.linspace(start, stop, num=num_steps).astype(int)
subset_nums
# Out:
# array([ 5, 12, 20, 28, 36, 44])

# %%
# extract training patients
df_pat_train, df_pat_val, df_pat_test = [df_patient.query('Split == @split') for split in ('TRAIN', 'VAL', 'TEST')]

#shuffle the train set
df_pat_train = df_pat_train.sample(frac=1, replace=False)

# form the new sample columns
for sn in subset_nums:
    column = f'patient_sample_{sn}'
    df_pat_train[column] = False
    df_pat_train.iloc[:sn, -1] = True
    
# recombine into single patient table
df_patient = pd.concat([df_pat_train, df_pat_val, df_pat_test])

# fill missings with True for val/test splits
df_patient = df_patient.fillna(True)

# %%
df_patient.head(20)
# Out:
#           patient_id patient_type  num_studies  cv_split  Split  \
# 53  d89a49b21f3a94ee          pda            1         1  TRAIN
# 57  ded498e8adf7852f          pda            1         2  TRAIN
# 54  d9d3ed4a1ab8b062        nopda            1         0  TRAIN
# 55  db6c7756ec256c5d        nopda            3         3  TRAIN
# 64  f87e8f22175b90d2        nopda            1         1  TRAIN
# 36  7b0bda0dcd4f6c57        nopda            1         2  TRAIN
# 58  e54c49ddb1688524          pda            1         3  TRAIN
# 50  bc469a5717698f88          pda            1         3  TRAIN
# 19  4725d50f8dacb4da        nopda            3         3  TRAIN
# 38  7ea606265b1074dc        nopda            1         3  TRAIN
# 3   0a3d6256c8e10c73          pda            5         0  TRAIN
# 9   291b90e87fbd335c        nopda            1         1  TRAIN
# 60  f06e90b7aecdafca          pda            1         1  TRAIN
# 21  4d0752e951369900          pda            2         1  TRAIN
# 35  7abbbf39f03f6b1d        nopda            1         2  TRAIN
# 42  918c0a054d2d48b2          pda            4         3  TRAIN
# 51  c171115e83689bbe        nopda            1         2  TRAIN
# 26  665af6ab4d17c5e5          pda            4         1  TRAIN
# 29  6bc2832e6102899c          pda            3         1  TRAIN
# 33  79cb039425011815          pda            1         0  TRAIN
#
#     patient_sample_5  patient_sample_12  patient_sample_20  patient_sample_28  \
# 53              True               True               True               True
# 57              True               True               True               True
# 54              True               True               True               True
# 55              True               True               True               True
# 64              True               True               True               True
# 36             False               True               True               True
# 58             False               True               True               True
# 50             False               True               True               True
# 19             False               True               True               True
# 38             False               True               True               True
# 3              False               True               True               True
# 9              False               True               True               True
# 60             False              False               True               True
# 21             False              False               True               True
# 35             False              False               True               True
# 42             False              False               True               True
# 51             False              False               True               True
# 26             False              False               True               True
# 29             False              False               True               True
# 33             False              False               True               True
#
#     patient_sample_36  patient_sample_44
# 53               True               True
# 57               True               True
# 54               True               True
# 55               True               True
# 64               True               True
# 36               True               True
# 58               True               True
# 50               True               True
# 19               True               True
# 38               True               True
# 3                True               True
# 9                True               True
# 60               True               True
# 21               True               True
# 35               True               True
# 42               True               True
# 51               True               True
# 26               True               True
# 29               True               True
# 33               True               True

# %%
# merge on video data
df_vid = df_patient.drop('patient_type', axis=1).\
    merge(df_patient_study, on='patient_id').\
    merge(df_study, on=['patient_type', 'study']).\
    merge(df_video, on=['patient_type', 'study'])

df_vid.shape
# Out:
# (5086, 21)

# %%
# number of videos by subset
for sn in subset_nums:
    column = f'patient_sample_{sn}'
    dfq = df_vid.query("mode != '2d' and view != 'nonPDAView'")
    print(dfq.groupby('Split')[column].sum())
# Out:
# Split
# TEST     272
# TRAIN     46
# VAL      118
# Name: patient_sample_5, dtype: int64
# Split
# TEST     272
# TRAIN    143
# VAL      118
# Name: patient_sample_12, dtype: int64
# Split
# TEST     272
# TRAIN    258
# VAL      118
# Name: patient_sample_20, dtype: int64
# Split
# TEST     272
# TRAIN    465
# VAL      118
# Name: patient_sample_28, dtype: int64
# Split
# TEST     272
# TRAIN    621
# VAL      118
# Name: patient_sample_36, dtype: int64
# Split
# TEST     272
# TRAIN    755
# VAL      118
# Name: patient_sample_44, dtype: int64

# %%
# merge on the frame data
df = df_vid.merge(df_frame, on=['patient_type', 'external_id'])

df = df.drop(['num_videos_x', 'num_videos_y', 'num_frames_x', 'num_frames_y', 'diagnosis'], axis=1)
df
# Out:
#               patient_id  num_studies  cv_split  Split  patient_sample_5  \
# 0       d89a49b21f3a94ee            1         1  TRAIN              True
# 1       d89a49b21f3a94ee            1         1  TRAIN              True
# 2       d89a49b21f3a94ee            1         1  TRAIN              True
# 3       d89a49b21f3a94ee            1         1  TRAIN              True
# 4       d89a49b21f3a94ee            1         1  TRAIN              True
# ...                  ...          ...       ...    ...               ...
# 471918  efa3614c94506474            1         5   TEST              True
# 471919  efa3614c94506474            1         5   TEST              True
# 471920  efa3614c94506474            1         5   TEST              True
# 471921  efa3614c94506474            1         5   TEST              True
# 471922  efa3614c94506474            1         5   TEST              True
#
#         patient_sample_12  patient_sample_20  patient_sample_28  \
# 0                    True               True               True
# 1                    True               True               True
# 2                    True               True               True
# 3                    True               True               True
# 4                    True               True               True
# ...                   ...                ...                ...
# 471918               True               True               True
# 471919               True               True               True
# 471920               True               True               True
# 471921               True               True               True
# 471922               True               True               True
#
#         patient_sample_36  patient_sample_44 patient_type    study  \
# 0                    True               True          pda  study47
# 1                    True               True          pda  study47
# 2                    True               True          pda  study47
# 3                    True               True          pda  study47
# 4                    True               True          pda  study47
# ...                   ...                ...          ...      ...
# 471918               True               True        nopda  study55
# 471919               True               True        nopda  study55
# 471920               True               True        nopda  study55
# 471921               True               True        nopda  study55
# 471922               True               True        nopda  study55
#
#              external_id            view   mode  \
# 0        study47_dicom17  pdaRelatedView     2d
# 1        study47_dicom17  pdaRelatedView     2d
# 2        study47_dicom17  pdaRelatedView     2d
# 3        study47_dicom17  pdaRelatedView     2d
# 4        study47_dicom17  pdaRelatedView     2d
# ...                  ...             ...    ...
# 471918  study55_dicom122      nonPDAView  color
# 471919  study55_dicom122      nonPDAView  color
# 471920  study55_dicom122      nonPDAView  color
# 471921  study55_dicom122      nonPDAView  color
# 471922  study55_dicom122      nonPDAView  color
#
#                                                  mp4_path  \
# 0       /zfs/wficai/pda/batch_1/PDA_Batch_1/Superior V...
# 1       /zfs/wficai/pda/batch_1/PDA_Batch_1/Superior V...
# 2       /zfs/wficai/pda/batch_1/PDA_Batch_1/Superior V...
# 3       /zfs/wficai/pda/batch_1/PDA_Batch_1/Superior V...
# 4       /zfs/wficai/pda/batch_1/PDA_Batch_1/Superior V...
# ...                                                   ...
# 471918  /zfs/wficai/pda/batch_1/Non-PDA_Batch_1/Superi...
# 471919  /zfs/wficai/pda/batch_1/Non-PDA_Batch_1/Superi...
# 471920  /zfs/wficai/pda/batch_1/Non-PDA_Batch_1/Superi...
# 471921  /zfs/wficai/pda/batch_1/Non-PDA_Batch_1/Superi...
# 471922  /zfs/wficai/pda/batch_1/Non-PDA_Batch_1/Superi...
#
#                                                  png_path
# 0       /zfs/wficai/pda/model_data/20221028/pda_study4...
# 1       /zfs/wficai/pda/model_data/20221028/pda_study4...
# 2       /zfs/wficai/pda/model_data/20221028/pda_study4...
# 3       /zfs/wficai/pda/model_data/20221028/pda_study4...
# 4       /zfs/wficai/pda/model_data/20221028/pda_study4...
# ...                                                   ...
# 471918  /zfs/wficai/pda/model_data/20221028/nopda_stud...
# 471919  /zfs/wficai/pda/model_data/20221028/nopda_stud...
# 471920  /zfs/wficai/pda/model_data/20221028/nopda_stud...
# 471921  /zfs/wficai/pda/model_data/20221028/nopda_stud...
# 471922  /zfs/wficai/pda/model_data/20221028/nopda_stud...
#
# [471923 rows x 17 columns]

# %%
# save splits
df.to_csv(output_csv, index=None)
